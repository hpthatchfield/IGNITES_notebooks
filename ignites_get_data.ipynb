# %%
import astropy.io.fits as fits
import numpy as np
import matplotlib.pyplot as plt
from aplpy import FITSFigure
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

# %matplotlib inline
# Out:
# <style>.container { width:100% !important; }</style>

# %%
data_path = '/Users/hph/Dropbox/astrophys/CMZoom/cmzoom_RGB/cmzoom_rgb_custom/'
m24 = fits.open(data_path+'mosaic_24um_reprojected.fits')

# %%
afig = FITSFigure(m24,convention='calabretta')
afig.show_colorscale()
aax = plt.gca()
#aax.set_ylim(-500,500)
# Out:
# INFO: Auto-setting vmin to -1.423e+02 [aplpy.core]
# INFO: Auto-setting vmax to  1.943e+03 [aplpy.core]

# %%
m24[0].header
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 m24[0].header
#
# NameError: name 'm24' is not defined
