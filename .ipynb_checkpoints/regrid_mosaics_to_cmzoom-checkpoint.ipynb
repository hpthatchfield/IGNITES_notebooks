# %%
from astropy.wcs import WCS
from astropy.io import fits
from reproject import reproject_interp
import cmasher as cmr
from scipy import signal
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.colors import LogNorm
from matplotlib import colors
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# !jt -l
# !jt -t
# Out:
# Available Themes:
#    chesterish
#    grade3
#    gruvboxd
#    gruvboxl
#    monokai
#    oceans16
#    onedork
#    solarizedd
#    solarizedl

# %%
### 
mosaic_path = '/Users/hph/Dropbox/astrophys/CMZoom/cmzoom_RGB/cmzoom_rgb_custom/'
cmzoom_path = '/Users/hph/Dropbox/astrophys/CMZoom/cmzoom_catalog/catalog_acc/'
cmzoom_leaf_mask = fits.open(cmzoom_path+'dendrogram_mask_pruned_rms3e6_k14_dv3_dd1_dp17_pp6_pm2_gal_02-02-20.fits')
mosaic_8um  = fits.open(mosaic_path+'gcmosaic_8um.fits')
mosaic_24um = fits.open(mosaic_path+'24micron_gal.fits')
mosaic_70um = fits.open(mosaic_path+'gcmosaic_70um.fits')

mosaic_25um = fits.open(mosaic_path+'F0588_FO_IMA_07018936_FORF253_MOS_0001-0348.fits')
mosaic_25um[0].data = mosaic_25um[0].data[0,:,:]
mosaic_25um[0].header['NAXIS']=2
#mosaic_25um[0].header.remove('NAXIS3')

mosaic_37um = fits.open(mosaic_path+'F0588_FO_IMA_07018936_FORF371_MOS_0001-0348.fits')
mosaic_37um[0].data = mosaic_37um[0].data[0,:,:]
mosaic_37um[0].header['NAXIS']=2
#mosaic_37um[0].header.remove('NAXIS3')

# %%
mosaic_70um[0].header
# Out:
# SIMPLE  =                    T / Written by IDL:  Sat Jul 23 22:32:49 2011
# BITPIX  =                  -32 / Real*4 (floating point)
# NAXIS   =                    2
# NAXIS1  =                 8000
# NAXIS2  =                 3000
# EXTEND  =                    T
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# CTYPE1  = 'GLON-TAN'
# CTYPE2  = 'GLAT-TAN'
# CRPIX1  =                4000.
# CRPIX2  =                1500.
# CRVAL1  =                  0.0
# CRVAL2  =                  0.0
# CDELT1  =   -0.000888888888889
# CDELT2  =    0.000888888888889
# CROTA2  =                    0
# BUNIT   = 'MJy/sr  '
# RPE_APPL=                    0 / RPE correction switch
# RPE_AL  =                    0 / No RPE correction is applied
# RPE_AC  =                    0 / No RPE correction is applied
# WAVELEN =                   70 / Wavelength of observation in microns
# SCANDIR1= 'Orth    '           / Scan diretion 1
# SCANDIR2= 'Nom     '           / Scan direction 2
# OBSDAY_1=                  481 / Observations day 1
# OBSDAY_2=                  481 / Observation day 2
# OBSID_1 = '1342204103'         / ObsID 1
# OBSID_2 = '1342204102'         / ObsID 2
# OBS_D_1 = '2010-09-07'         / Obs start day 1
# OBS_T_1 = '06:47:44'           / Obs start time 1
# OBS_D_2 = '2010-09-07'         / Obs start day 2
# OBS_T_2 = '04:08:11'           / Obs start time 2
# OFSET_AP=                    1 / Offset application switch
# OFSET_VA=              111.094 / Offset from intercal IRAS-Planck-HSO
# GAIN_AP =                    0 / Gain application switch
# GAIN_VA =                    1 / Gain from intercal IRAS-Planck-HSO
# MED_WIN =                   20 / Median filter width
# MED_STEP=                   20 / Median step
# FLAG_PER=                   38 / Maximum flagging alowed in timeline
# MASK_CL =                    3 / Clipping level for mask definition
# MASK_GR =                    3 / Growing factor for mask definition
# REGS_LON=             0.262382 / Registration shift in g-lon (arcsec)
# REGS_LAT=            -0.392711 / Registration shift in g-lat (arcsec)

# %%
wcs = WCS(cmzoom_leaf_mask[0].header)

# %%
array, footprint = reproject_interp(mosaic_8um, cmzoom_leaf_mask[0].header)
fits.writeto(mosaic_path+'mosaic_8um_reprojected.fits', array, wcs.to_header(), overwrite=True)

# %%
array, footprint = reproject_interp(mosaic_24um, cmzoom_leaf_mask[0].header)
fits.writeto(mosaic_path+'mosaic_24um_reprojected.fits', array, wcs.to_header(), overwrite=True)

# %%
array, footprint = reproject_interp(mosaic_70um, cmzoom_leaf_mask[0].header)
fits.writeto(mosaic_path+'mosaic_70um_reprojected.fits', array, wcs.to_header(), overwrite=True)

# %%
array, footprint = reproject_interp(mosaic_25um, cmzoom_leaf_mask[0].header)
fits.writeto(mosaic_path+'mosaic_25um_reprojected.fits', array, wcs.to_header(), overwrite=True)

# %%
array, footprint = reproject_interp(mosaic_37um, cmzoom_leaf_mask[0].header)
fits.writeto(mosaic_path+'mosaic_37um_reprojected.fits', array, wcs.to_header(), overwrite=True)

# %%
leaf_23935_8um = mosaic_8um[0].data[np.where(cmzoom_leaf_mask[0].data==23935)[0]]

# %%
fig, ax = plt.subplots(figsize=(5,5))
bins = np.logspace(np.log10(np.min(leaf_23935_8um)),np.log10(np.max(leaf_23935_8um)),10)
ax.hist(leaf_23935_8um.flatten(),log=True,histtype='step',bins=bins,color='k')
ax.hist(leaf_23935_8um.flatten(),log=True,bins=bins,color='cornflowerblue')
ax.set_xscale('log')
ax.set_yscale('log')

# %%
### convolve images to worst resolution
mosaic_8um[0].header['CDELT1']*3600
beam_70um = 5.6 ## arcsec
kernel = np.outer(signal.windows.gaussian(20, 2),
                  signal.windows.gaussian(20, 2))

# %%
plt.imshow(kernel)

# %%
array, footprint = reproject_interp(mosaic_8um, cmzoom_leaf_mask[0].header)

#fits.writeto(mosaic_path+'mosaic_8um_reprojected.fits', array, wcs.to_header(), overwrite=True)

# %%
from astropy.convolution import convolve_fft

#mosaic_8_conv = signal.fftconvolve(array, kernel,mode='same')
mosaic_8_conv = convolve_fft(array,

# %%
fig, ax = plt.subplots(nrows=3,ncols=1,figsize=(15,8))
norm = colors.LogNorm(vmin=10, vmax=1e3)
ax[0].imshow(array, cmap=cmr.cosmic,norm=norm)
ax[0].set_title('Original')

ax[1].imshow(mosaic_8_conv, cmap=cmr.cosmic,norm=norm)
ax[1].set_title('Convolved with 70um PSF')

ax[2].imshow((array/mosaic_8_conv), cmap='viridis', norm=colors.Normalize(vmin=0.01, vmax=0.1))
ax[2].set_title('Ratio of Original / Convolved')

plt.tight_layout()

# %%
plt.hist((array/mosaic_8_conv).flatten(),log=True)
# Out:
# (array([4.307000e+03, 5.178059e+07, 1.350794e+06, 4.252600e+04,
#         2.159800e+04, 1.740000e+02, 9.000000e+00, 1.000000e+00,
#         0.000000e+00, 1.000000e+00]),
#  array([0.01143074, 0.02618748, 0.04094422, 0.05570096, 0.0704577 ,
#         0.08521444, 0.09997119, 0.11472793, 0.12948467, 0.14424141,
#         0.15899815]),
#  <BarContainer object of 10 artists>)

# %%
plt.imshow((array/mosaic_8_conv), cmap='viridis')
